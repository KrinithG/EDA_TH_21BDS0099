# %% [markdown]
# <a href="https://colab.research.google.com/github/KrinithG/EDA_TH_21BDS0099/blob/main/21BDS0099.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
krinith_df=pd.read_csv('https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Males.csv')

# %%
print(krinith_df.columns)
# Out:
# Index(['rownames', 'nr', 'year', 'school', 'exper', 'union', 'ethn', 'maried',
#        'health', 'wage', 'industry', 'occupation', 'residence'],
#       dtype='object')

# %%
krinith_df1=krinith_df

# %%
krinith_df.head(10)
# Out:
#    rownames  nr  year  school  exper union   ethn maried health      wage  \
# 0         1  13  1980      14      1    no  other     no     no  1.197540
# 1         2  13  1981      14      2   yes  other     no     no  1.853060
# 2         3  13  1982      14      3    no  other     no     no  1.344462
# 3         4  13  1983      14      4    no  other     no     no  1.433213
# 4         5  13  1984      14      5    no  other     no     no  1.568125
# 5         6  13  1985      14      6    no  other     no     no  1.699891
# 6         7  13  1986      14      7    no  other     no     no -0.720263
# 7         8  13  1987      14      8    no  other     no     no  1.669188
# 8         9  17  1980      13      4    no  other     no     no  1.675962
# 9        10  17  1981      13      5    no  other     no     no  1.518398
#
#                       industry                           occupation  \
# 0  Business_and_Repair_Service                      Service_Workers
# ...

# %%
krinith_df.describe()
# Out:
#           rownames            nr         year       school        exper  \
# count  4360.000000   4360.000000  4360.000000  4360.000000  4360.000000
# mean   2180.500000   5262.058716  1983.500000    11.766972     6.514679
# std    1258.767916   3496.149815     2.291551     1.746181     2.825873
# min       1.000000     13.000000  1980.000000     3.000000     0.000000
# 25%    1090.750000   2329.000000  1981.750000    11.000000     4.000000
# 50%    2180.500000   4569.000000  1983.500000    12.000000     6.000000
# 75%    3270.250000   8406.000000  1985.250000    12.000000     9.000000
# max    4360.000000  12548.000000  1987.000000    16.000000    18.000000
#
#               wage
# count  4360.000000
# mean      1.649147
# std       0.532609
# min      -3.579079
# 25%       1.350717
# 50%       1.671143
# 75%       1.991086
# max       4.051860

# %%
# Splitting the dataset into two dataframes
df1 = krinith_df.iloc[:len(krinith_df)//2]
df2 = krinith_df.iloc[len(krinith_df)//2:]

# %% [markdown]
# # **Merging Two dataframes as Database**

# %%
# Merging one after the other or row wise
df3 = pd.concat([df1, df2], ignore_index=True)
df3
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4355      4356  12548  1983       9      8    no  other    yes     no
# 4356      4357  12548  1984       9      9   yes  other    yes     no
# 4357      4358  12548  1985       9     10    no  other    yes     no
# 4358      4359  12548  1986       9     11   yes  other    yes     no
# 4359      4360  12548  1987       9     12   yes  other    yes     no
#
#           wage                          industry  \
# 0     1.197540       Business_and_Repair_Service
# ...

# %%
# Merging side by side or column wise
pd.concat([df1, df2], axis=1)
# Out:
#       rownames    nr    year school exper union   ethn  maried  health  \
# 0          1.0  13.0  1980.0   14.0   1.0    no  other      no      no
# 1          2.0  13.0  1981.0   14.0   2.0   yes  other      no      no
# 2          3.0  13.0  1982.0   14.0   3.0    no  other      no      no
# 3          4.0  13.0  1983.0   14.0   4.0    no  other      no      no
# 4          5.0  13.0  1984.0   14.0   5.0    no  other      no      no
# ...        ...   ...     ...    ...   ...   ...    ...     ...     ...
# 4355       NaN   NaN     NaN    NaN   NaN   NaN    NaN     NaN     NaN
# 4356       NaN   NaN     NaN    NaN   NaN   NaN    NaN     NaN     NaN
# 4357       NaN   NaN     NaN    NaN   NaN   NaN    NaN     NaN     NaN
# 4358       NaN   NaN     NaN    NaN   NaN   NaN    NaN     NaN     NaN
# 4359       NaN   NaN     NaN    NaN   NaN   NaN    NaN     NaN     NaN
#
#           wage  ... school exper union   ethn  maried  health      wage  \
# ...

# %% [markdown]
# # **Merging dataframes using Join**

# %%
# Splitting the dataset into 4 dataframes
dfkg1 = krinith_df.iloc[: len(krinith_df)//4]
dfkg2 = krinith_df.iloc[len(krinith_df)//4:len(krinith_df)//2]
dfkg3 = krinith_df.iloc[len(krinith_df)//2:3*len(krinith_df)//4]
dfkg4 = krinith_df.iloc[3*len(krinith_df)//4:]

# %%
#Using Concat()
dfkg22 = pd.concat([dfkg1, dfkg2], ignore_index=True)
dfkg44 = pd.concat([dfkg3, dfkg4], ignore_index=True)

# %%
dfkg22
# Out:
#       rownames    nr  year  school  exper union   ethn maried health  \
# 0            1    13  1980      14      1    no  other     no     no
# 1            2    13  1981      14      2   yes  other     no     no
# 2            3    13  1982      14      3    no  other     no     no
# 3            4    13  1983      14      4    no  other     no     no
# 4            5    13  1984      14      5    no  other     no     no
# ...        ...   ...   ...     ...    ...   ...    ...    ...    ...
# 2175      2176  4563  1987      11      8   yes  other    yes     no
# 2176      2177  4569  1980      12      1   yes  other     no     no
# 2177      2178  4569  1981      12      2   yes  other     no     no
# 2178      2179  4569  1982      12      3   yes  other    yes     no
# 2179      2180  4569  1983      12      4   yes  other     no     no
#
#           wage                     industry                      occupation  \
# ...

# %%
dfkg44
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0         2181   4569  1984      12      5   yes  other     no     no
# 1         2182   4569  1985      12      6   yes  other     no     no
# 2         2183   4569  1986      12      7   yes  other    yes     no
# 3         2184   4569  1987      12      8   yes  other    yes     no
# 4         2185   4603  1980      11      2   yes  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 2175      4356  12548  1983       9      8    no  other    yes     no
# 2176      4357  12548  1984       9      9   yes  other    yes     no
# 2177      4358  12548  1985       9     10    no  other    yes     no
# 2178      4359  12548  1986       9     11   yes  other    yes     no
# 2179      4360  12548  1987       9     12   yes  other    yes     no
#
#           wage                          industry  \
# 0     2.367185                             Trade
# ...

# %%
#Using Inner join
dfkg_inner = dfkg22.merge(dfkg44, how='inner')
print(dfkg_inner.head())
# Out:
# Empty DataFrame
# Columns: [rownames, nr, year, school, exper, union, ethn, maried, health, wage, industry, occupation, residence]
# Index: []

# %%
#Using Left join
dfkg_left = dfkg22.merge(dfkg44, how='left')
print(dfkg_left.head())
# Out:
#    rownames  nr  year  school  exper union   ethn maried health      wage  \
# 0         1  13  1980      14      1    no  other     no     no  1.197540
# 1         2  13  1981      14      2   yes  other     no     no  1.853060
# 2         3  13  1982      14      3    no  other     no     no  1.344462
# 3         4  13  1983      14      4    no  other     no     no  1.433213
# 4         5  13  1984      14      5    no  other     no     no  1.568125
#
#                       industry                      occupation   residence
# 0  Business_and_Repair_Service                 Service_Workers  north_east
# 1             Personal_Service                 Service_Workers  north_east
# 2  Business_and_Repair_Service                 Service_Workers  north_east
# 3  Business_and_Repair_Service                 Service_Workers  north_east
# 4             Personal_Service  Craftsmen, Foremen_and_kindred  north_east

# %%
#Using Right Join
dfkg_right = dfkg22.merge(dfkg44, how='right')
print(dfkg_right.head())
# Out:
#    rownames    nr  year  school  exper union   ethn maried health      wage  \
# 0      2181  4569  1984      12      5   yes  other     no     no  2.367185
# 1      2182  4569  1985      12      6   yes  other     no     no  2.129068
# 2      2183  4569  1986      12      7   yes  other    yes     no  2.033576
# 3      2184  4569  1987      12      8   yes  other    yes     no  2.035432
# 4      2185  4603  1980      11      2   yes  other     no     no  2.055204
#
#   industry                           occupation residence
# 0    Trade                 Laborers_and_farmers       NaN
# 1    Trade                 Laborers_and_farmers       NaN
# 2    Trade                 Laborers_and_farmers       NaN
# 3    Trade  Managers, Officials_and_Proprietors       NaN
# 4    Trade                 Laborers_and_farmers       NaN

# %%
#Using Outer Join
dfkg_outer = dfkg22.merge(dfkg44, how='outer')
print(dfkg_outer.head())
# Out:
#    rownames  nr  year  school  exper union   ethn maried health      wage  \
# 0         1  13  1980      14      1    no  other     no     no  1.197540
# 1         2  13  1981      14      2   yes  other     no     no  1.853060
# 2         3  13  1982      14      3    no  other     no     no  1.344462
# 3         4  13  1983      14      4    no  other     no     no  1.433213
# 4         5  13  1984      14      5    no  other     no     no  1.568125
#
#                       industry                      occupation   residence
# 0  Business_and_Repair_Service                 Service_Workers  north_east
# 1             Personal_Service                 Service_Workers  north_east
# 2  Business_and_Repair_Service                 Service_Workers  north_east
# 3  Business_and_Repair_Service                 Service_Workers  north_east
# 4             Personal_Service  Craftsmen, Foremen_and_kindred  north_east

# %% [markdown]
# # **Reshaping with Hierarchical Indexing**

# %%
dfkg_respd = krinith_df.set_index(['rownames', 'maried']).sort_index()
print(dfkg_respd.head())
# Out:
#                  nr  year  school  exper union   ethn health      wage  \
# rownames maried
# 1        no      13  1980      14      1    no  other     no  1.197540
# 2        no      13  1981      14      2   yes  other     no  1.853060
# 3        no      13  1982      14      3    no  other     no  1.344462
# 4        no      13  1983      14      4    no  other     no  1.433213
# 5        no      13  1984      14      5    no  other     no  1.568125
#
#                                     industry                      occupation  \
# rownames maried
# 1        no      Business_and_Repair_Service                 Service_Workers
# 2        no                 Personal_Service                 Service_Workers
# 3        no      Business_and_Repair_Service                 Service_Workers
# 4        no      Business_and_Repair_Service                 Service_Workers
# 5        no                 Personal_Service  Craftsmen, Foremen_and_kindred
#
#                   residence
# ...

# %%
stacked = dfkg_respd.stack()
stacked
# Out:
# rownames  maried
# 1         no      nr                                        13
#                   year                                    1980
#                   school                                    14
#                   exper                                      1
#                   union                                     no
#                                              ...
# 4360      yes     ethn                                   other
#                   health                                    no
#                   wage                                1.466543
#                   industry               Public_Administration
#                   occupation    Craftsmen, Foremen_and_kindred
# Length: 46715, dtype: object

# %%
stacked.unstack()
# Out:
#                     nr  year school exper union   ethn health      wage  \
# rownames maried
# 1        no         13  1980     14     1    no  other     no   1.19754
# 2        no         13  1981     14     2   yes  other     no   1.85306
# 3        no         13  1982     14     3    no  other     no  1.344462
# 4        no         13  1983     14     4    no  other     no  1.433213
# 5        no         13  1984     14     5    no  other     no  1.568125
# ...                ...   ...    ...   ...   ...    ...    ...       ...
# 4356     yes     12548  1983      9     8    no  other     no  1.591879
# 4357     yes     12548  1984      9     9   yes  other     no  1.212543
# 4358     yes     12548  1985      9    10    no  other     no  1.765962
# 4359     yes     12548  1986      9    11   yes  other     no  1.745894
# 4360     yes     12548  1987      9    12   yes  other     no  1.466543
#
#                                          industry  \
# rownames maried
# ...

# %% [markdown]
# # **Transformation Techniques**

# %% [markdown]
# **1) Data DeDuplication**

# %%
krinith_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4355    False
# 4356    False
# 4357    False
# 4358    False
# 4359    False
# Length: 4360, dtype: bool

# %%
krinith_df.duplicated().sum().sum()
# Out:
# np.int64(0)

# %%
krinith_dedup_df=krinith_df.drop_duplicates()
krinith_dedup_df
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4355      4356  12548  1983       9      8    no  other    yes     no
# 4356      4357  12548  1984       9      9   yes  other    yes     no
# 4357      4358  12548  1985       9     10    no  other    yes     no
# 4358      4359  12548  1986       9     11   yes  other    yes     no
# 4359      4360  12548  1987       9     12   yes  other    yes     no
#
#           wage                          industry  \
# 0     1.197540       Business_and_Repair_Service
# ...

# %% [markdown]
# **2) Replacing values**

# %%
krinith_df.replace(to_replace = 1981, value = np.nan)
# Out:
#       rownames     nr    year  school  exper union   ethn maried health  \
# 0          1.0     13  1980.0      14      1    no  other     no     no
# 1          2.0     13     NaN      14      2   yes  other     no     no
# 2          3.0     13  1982.0      14      3    no  other     no     no
# 3          4.0     13  1983.0      14      4    no  other     no     no
# 4          5.0     13  1984.0      14      5    no  other     no     no
# ...        ...    ...     ...     ...    ...   ...    ...    ...    ...
# 4355    4356.0  12548  1983.0       9      8    no  other    yes     no
# 4356    4357.0  12548  1984.0       9      9   yes  other    yes     no
# 4357    4358.0  12548  1985.0       9     10    no  other    yes     no
# 4358    4359.0  12548  1986.0       9     11   yes  other    yes     no
# 4359    4360.0  12548  1987.0       9     12   yes  other    yes     no
#
#           wage                          industry  \
# 0     1.197540       Business_and_Repair_Service
# ...

# %% [markdown]
# **3) Handling missing data**

# %%
krinith_df.isnull()
# Out:
#       rownames     nr   year  school  exper  union   ethn  maried  health  \
# 0        False  False  False   False  False  False  False   False   False
# 1        False  False  False   False  False  False  False   False   False
# 2        False  False  False   False  False  False  False   False   False
# 3        False  False  False   False  False  False  False   False   False
# 4        False  False  False   False  False  False  False   False   False
# ...        ...    ...    ...     ...    ...    ...    ...     ...     ...
# 4355     False  False  False   False  False  False  False   False   False
# 4356     False  False  False   False  False  False  False   False   False
# 4357     False  False  False   False  False  False  False   False   False
# 4358     False  False  False   False  False  False  False   False   False
# 4359     False  False  False   False  False  False  False   False   False
#
#        wage  industry  occupation  residence
# ...

# %%
krinith_df.notnull()
# Out:
#       rownames    nr  year  school  exper  union  ethn  maried  health  wage  \
# 0         True  True  True    True   True   True  True    True    True  True
# 1         True  True  True    True   True   True  True    True    True  True
# 2         True  True  True    True   True   True  True    True    True  True
# 3         True  True  True    True   True   True  True    True    True  True
# 4         True  True  True    True   True   True  True    True    True  True
# ...        ...   ...   ...     ...    ...    ...   ...     ...     ...   ...
# 4355      True  True  True    True   True   True  True    True    True  True
# 4356      True  True  True    True   True   True  True    True    True  True
# 4357      True  True  True    True   True   True  True    True    True  True
# 4358      True  True  True    True   True   True  True    True    True  True
# 4359      True  True  True    True   True   True  True    True    True  True
#
#       industry  occupation  residence
# ...

# %%
krinith_df.isnull().sum()
# Out:
# rownames         0
# nr               0
# year             0
# school           0
# exper            0
# union            0
# ethn             0
# maried           0
# health           0
# wage             0
# industry         0
# occupation       0
# residence     1245
# dtype: int64

# %%
krinith_df.isnull().sum().sum()
# Out:
# np.int64(1245)

# %%
krinith_df.count()
# Out:
# rownames      4360
# nr            4360
# year          4360
# school        4360
# exper         4360
# union         4360
# ethn          4360
# maried        4360
# health        4360
# wage          4360
# industry      4360
# occupation    4360
# residence     3115
# dtype: int64

# %%
krinith_df = krinith_df.dropna()
print(krinith_df)
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4331      4332  12477  1983      12      7   yes  other    yes     no
# 4332      4333  12477  1984      12      8   yes  other    yes     no
# 4333      4334  12477  1985      12      9   yes  other    yes     no
# 4334      4335  12477  1986      12     10   yes  other    yes     no
# 4335      4336  12477  1987      12     11   yes  other    yes     no
#
#           wage                     industry                      occupation  \
# ...

# %%
#Dropping by rows
krinith_df.dropna(how='all')
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4331      4332  12477  1983      12      7   yes  other    yes     no
# 4332      4333  12477  1984      12      8   yes  other    yes     no
# 4333      4334  12477  1985      12      9   yes  other    yes     no
# 4334      4335  12477  1986      12     10   yes  other    yes     no
# 4335      4336  12477  1987      12     11   yes  other    yes     no
#
#           wage                     industry                      occupation  \
# ...

# %%
#Dropping by columns
krinith_df.dropna(how='all', axis=1)
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4331      4332  12477  1983      12      7   yes  other    yes     no
# 4332      4333  12477  1984      12      8   yes  other    yes     no
# 4333      4334  12477  1985      12      9   yes  other    yes     no
# 4334      4335  12477  1986      12     10   yes  other    yes     no
# 4335      4336  12477  1987      12     11   yes  other    yes     no
#
#           wage                     industry                      occupation  \
# ...

# %%
krinith_df.dropna(thresh=10, axis=1)
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4331      4332  12477  1983      12      7   yes  other    yes     no
# 4332      4333  12477  1984      12      8   yes  other    yes     no
# 4333      4334  12477  1985      12      9   yes  other    yes     no
# 4334      4335  12477  1986      12     10   yes  other    yes     no
# 4335      4336  12477  1987      12     11   yes  other    yes     no
#
#           wage                     industry                      occupation  \
# ...

# %%
#filling na with values
filledDf = krinith_df.fillna('north_east')
filledDf
# Out:
#       rownames     nr  year  school  exper union   ethn maried health  \
# 0            1     13  1980      14      1    no  other     no     no
# 1            2     13  1981      14      2   yes  other     no     no
# 2            3     13  1982      14      3    no  other     no     no
# 3            4     13  1983      14      4    no  other     no     no
# 4            5     13  1984      14      5    no  other     no     no
# ...        ...    ...   ...     ...    ...   ...    ...    ...    ...
# 4331      4332  12477  1983      12      7   yes  other    yes     no
# 4332      4333  12477  1984      12      8   yes  other    yes     no
# 4333      4334  12477  1985      12      9   yes  other    yes     no
# 4334      4335  12477  1986      12     10   yes  other    yes     no
# 4335      4336  12477  1987      12     11   yes  other    yes     no
#
#           wage                     industry                      occupation  \
# ...

# %%
filledDf.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
krinith_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3115 entries, 0 to 4335
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rownames    3115 non-null   int64
#  1   nr          3115 non-null   int64
#  2   year        3115 non-null   int64
#  3   school      3115 non-null   int64
#  4   exper       3115 non-null   int64
#  5   union       3115 non-null   object
#  6   ethn        3115 non-null   object
#  7   maried      3115 non-null   object
#  8   health      3115 non-null   object
#  9   wage        3115 non-null   float64
#  10  industry    3115 non-null   object
#  11  occupation  3115 non-null   object
#  12  residence   3115 non-null   object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 340.7+ KB

# %%
krinith_df['residence'] = krinith_df['residence'].fillna(krinith_df['residence'].mode()[0])
# Out:
# <ipython-input-39-ab071d5de25a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   krinith_df['residence'] = krinith_df['residence'].fillna(krinith_df['residence'].mode()[0])

# %%
krinith_df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#forward-filling
krinith_df.residence.fillna(method='ffill')
# Out:
# <ipython-input-41-bb7651f4c4e0>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   krinith_df.residence.fillna(method='ffill')
# 0       north_east
# 1       north_east
# 2       north_east
# 3       north_east
# 4       north_east
#            ...
# 4331    north_east
# 4332    north_east
# 4333    north_east
# 4334    north_east
# 4335    north_east
# Name: residence, Length: 3115, dtype: object

# %%
# backward filling
krinith_df.residence.fillna(method='bfill')
# Out:
# <ipython-input-42-907566d570ea>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   krinith_df.residence.fillna(method='bfill')
# 0       north_east
# 1       north_east
# 2       north_east
# 3       north_east
# 4       north_east
#            ...
# 4331    north_east
# 4332    north_east
# 4333    north_east
# 4334    north_east
# 4335    north_east
# Name: residence, Length: 3115, dtype: object

# %% [markdown]
# # **Discretization and binning**

# %%
val=krinith_df['nr']

# %%
bins = [118, 125, 135, 160, 200]
category = pd.cut(val, bins)
category
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 4331    NaN
# 4332    NaN
# 4333    NaN
# 4334    NaN
# 4335    NaN
# Name: nr, Length: 3115, dtype: category
# Categories (4, interval[int64, right]): [(118, 125] < (125, 135] < (135, 160] < (160, 200]]

# %% [markdown]
# # **Outlier detection and filtering**

# %%
# Compute Q1 (25th percentile) and Q3 (75th percentile)
Q1 = krinith_df['nr'].quantile(0.25)
Q3 = krinith_df['nr'].quantile(0.75)

# Compute IQR
IQR = Q3 - Q1

#Bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = krinith_df[(krinith_df['nr'] < lower_bound) | (krinith_df['nr'] > upper_bound)]

print(outliers[['nr']])

df = krinith_df[(krinith_df['nr'] >= lower_bound) & (krinith_df['nr'] <= upper_bound)]

print(df[['nr']])
# Out:
# Empty DataFrame
# Columns: [nr]
# Index: []
#          nr
# 0        13
# 1        13
# 2        13
# 3        13
# 4        13
# ...     ...
# 4331  12477
# 4332  12477
# 4333  12477
# 4334  12477
# 4335  12477
#
# [3115 rows x 1 columns]

# %% [markdown]
# # **Univariate Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Bar Chart**

# %% [markdown]
# Categorical variable

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="maried", data=krinith_df, palette="viridis")  # Replace with any categorical column
plt.title("21BDS0099 - Bar Chart of Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-47-cd653c054008>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="maried", data=krinith_df, palette="viridis")  # Replace with any categorical column

# %% [markdown]
# ### **Distribution Plot**

# %% [markdown]
# Continuous Variable

# %%
plt.figure(figsize=(8, 5))
sns.histplot(krinith_df["wage"], kde=True, bins=30, color="blue")
plt.title("21BDS0099-Distribution Plot of Wage")
plt.xlabel("Wage")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## **Box Plot**

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=krinith_df["wage"], color="orange")
plt.title("21BDS0099-Box Plot of Wage")
plt.ylabel("Wage")
plt.show()

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# **Scatter Plot**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=krinith_df["exper"], y=krinith_df["wage"], color="blue")
plt.title("21BDS0099-Scatter Plot of Experience vs Wage")
plt.xlabel("Experience (years)")
plt.ylabel("Wage")
plt.show()

# %% [markdown]
# ## **Box Plot**

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=krinith_df["maried"], y=krinith_df["wage"], palette="Set2")
plt.title("21BDS0099-Box Plot of Wage by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Wage")
plt.show()
# Out:
# <ipython-input-51-4e983b696852>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=krinith_df["maried"], y=krinith_df["wage"], palette="Set2")

# %% [markdown]
# ### **Multivariate Analysis**

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(krinith_df, diag_kind="kde", corner=True)
plt.suptitle("21BDS0099-Pair Plot of Numerical Variables", y=1.02)
plt.show()

# %% [markdown]
# **Correlation using Pearson method**

# %%
pearson_corr = df.corr(method="pearson", numeric_only=True)
print(pearson_corr)
# Out:
#           rownames        nr      year    school     exper      wage
# rownames  1.000000  0.987521 -0.007740  0.001906  0.030000 -0.065497
# nr        0.987521  1.000000 -0.009333  0.012415  0.026132 -0.068028
# year     -0.007740 -0.009333  1.000000  0.001531  0.847632  0.271367
# school    0.001906  0.012415  0.001531  1.000000 -0.244450  0.260882
# exper     0.030000  0.026132  0.847632 -0.244450  1.000000  0.196632
# wage     -0.065497 -0.068028  0.271367  0.260882  0.196632  1.000000

# %% [markdown]
# **Visualizing correlation using Heat Map**

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(pearson_corr, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f",
            xticklabels=pearson_corr.columns, yticklabels=pearson_corr.columns)
plt.title("21BDS0099-Pearson Correlation Heatmap")
plt.show()

# %% [markdown]
# # **Time Series Analysis**

# %%
import os
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
print(krinith_df1.columns)
# Out:
# Index(['rownames', 'nr', 'year', 'school', 'exper', 'union', 'ethn', 'maried',
#        'health', 'wage', 'industry', 'occupation', 'residence'],
#       dtype='object')

# %%
krinith_df1['year'] = pd.to_datetime(krinith_df1['year'], format='%Y')

# %%
krinith_df1 = krinith_df1.set_index('year')

# %%
krinith_df1.tail(5)
# Out:
#             rownames     nr  school  exper union   ethn maried health  \
# year
# 1983-01-01      4356  12548       9      8    no  other    yes     no
# 1984-01-01      4357  12548       9      9   yes  other    yes     no
# 1985-01-01      4358  12548       9     10    no  other    yes     no
# 1986-01-01      4359  12548       9     11   yes  other    yes     no
# 1987-01-01      4360  12548       9     12   yes  other    yes     no
#
#                 wage                          industry  \
# year
# 1983-01-01  1.591879                      Construction
# 1984-01-01  1.212543                      Construction
# 1985-01-01  1.765962                      Construction
# 1986-01-01  1.745894  Professional_and_Related Service
# 1987-01-01  1.466543             Public_Administration
#
#                                 occupation residence
# year
# 1983-01-01  Craftsmen, Foremen_and_kindred       NaN
# 1984-01-01  Craftsmen, Foremen_and_kindred       NaN
# ...

# %%
krinith_df1.index
# Out:
# DatetimeIndex(['1980-01-01', '1981-01-01', '1982-01-01', '1983-01-01',
#                '1984-01-01', '1985-01-01', '1986-01-01', '1987-01-01',
#                '1980-01-01', '1981-01-01',
#                ...
#                '1986-01-01', '1987-01-01', '1980-01-01', '1981-01-01',
#                '1982-01-01', '1983-01-01', '1984-01-01', '1985-01-01',
#                '1986-01-01', '1987-01-01'],
#               dtype='datetime64[ns]', name='year', length=4360, freq=None)

# %%
krinith_df1.loc['1981-01-01']
# Out:
#             rownames     nr  school  exper union   ethn maried health  \
# year
# 1981-01-01         2     13      14      2   yes  other     no     no
# 1981-01-01        10     17      13      5    no  other     no     no
# 1981-01-01        18     18      12      5    no  other    yes     no
# 1981-01-01        26     45      12      3   yes  other     no     no
# 1981-01-01        34    110      12      6    no  other     no     no
# ...              ...    ...     ...    ...   ...    ...    ...    ...
# 1981-01-01      4322  12451      14      3    no  other     no     no
# 1981-01-01      4330  12477      12      5   yes  other     no     no
# 1981-01-01      4338  12500      12      5    no  other     no     no
# 1981-01-01      4346  12534      11      3    no  other     no     no
# 1981-01-01      4354  12548       9      6    no  other     no     no
#
#                 wage                          industry  \
# year
# 1981-01-01  1.853060                  Personal_Service
# ...

# %% [markdown]
# ### **Time Series Line Plot**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)})
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 150

# %%
krinith_df1['wage'].plot(linewidth=0.25)
# Out:
# <Axes: xlabel='year'>

# %%
cols_to_plot = ['wage', 'school', 'nr']
axes = krinith_df1[cols_to_plot].plot(marker='*', alpha=0.5,
linestyle='None',figsize=(14, 6), subplots=True)

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 7), sharex=True)
for name, ax in zip(['wage', 'school', 'nr'], axes):
  sns.boxplot(data=krinith_df1, x='year', y=name, ax=ax)
  ax.set_title(name)
  if ax != axes[-1]:
    ax.set_xlabel('')

# %% [markdown]
# # **Data Summarization and Visualization**

# %% [markdown]
# ## **1-D Statistical Analysis**

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
mean_krinith= np.mean(krinith_df.wage)
median_krinith = np.median(krinith_df.wage)

# %%
variance_krinith = np.var(krinith_df.wage, ddof=1)
std_krinith= np.std(krinith_df.wage, ddof=1)
skewness_krinith = stats.skew(krinith_df.wage)
kurtosis_krinith = stats.kurtosis(krinith_df.wage)

# %%
print(f"Mean: {mean_krinith:.2f}")
print(f"Median: {median_krinith}")
print(f"Variance: {variance_krinith:.2f}")
print(f"Standard Deviation: {std_krinith:.2f}")
print(f"Skewness: {skewness_krinith:.2f}")
print(f"Kurtosis: {kurtosis_krinith:.2f}")
# Out:
# Mean: 1.65
# Median: 1.6804583482
# Variance: 0.28
# Standard Deviation: 0.53
# Skewness: -0.97
# Kurtosis: 5.59

# %%
# Histogram Plot
plt.hist(krinith_df.wage, bins=7, edgecolor='black', alpha=0.7)
plt.axvline(mean_krinith, color='red', linestyle='dashed', linewidth=2, label=f"Mean: {mean_krinith:.2f}")
plt.axvline(median_krinith, color='blue', linestyle='dashed', linewidth=2, label=f"Median: {median_krinith}")
plt.xlabel("Wages")
plt.ylabel("Frequency")
plt.title("21BDS0099-1-D Statistical Analysis Histogram")
plt.legend()
plt.show()

# %% [markdown]
# ## 2-D Analysis

# %%
from sklearn.linear_model import LinearRegression

# %%
# Covariance & Correlation
df = krinith_df[['nr', 'wage']]
cov_matrix = df.cov()
corr_matrix = df.corr()
print("\n Covariance Matrix:\n", cov_matrix)
print("\n Correlation Matrix:\n", corr_matrix)
# Out:
#  Covariance Matrix:
#                  nr        wage
# nr    1.163034e+07 -123.517282
# wage -1.235173e+02    0.283457
#
#  Correlation Matrix:
#              nr      wage
# nr    1.000000 -0.068028
# wage -0.068028  1.000000

# %%
# Linear Regression (Best-Fit Line)
X = krinith_df['nr'].values.reshape(-1, 1)
Y = krinith_df['wage'].values.reshape(-1, 1)
regressor = LinearRegression()
regressor.fit(X, Y)
predicted_Y = regressor.predict(X)
slope, intercept = regressor.coef_[0][0], regressor.intercept_[0]
print(f"\n Regression Line: {'nr'} = {slope:.2f} × {'wage,'} + {intercept:.2f}")
# Out:
#  Regression Line: nr = -0.00 × wage, + 1.70

# %%
# Scatter Plot with Regression Line
plt.figure(figsize=(8, 5))
plt.scatter(krinith_df['wage'], krinith_df['nr'], color="blue", label="Data Points")
plt.plot(krinith_df['wage'], predicted_Y, color="red", linewidth=2, label="Regression Line")
plt.xlabel('wage')
plt.ylabel('nr')
plt.title("21BDS0099-Scatter Plot with Regression Line")
plt.legend()
plt.show()

# %%
# Heatmap of Correlation Matrix
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("21BDS0099-Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# # **Clustering Algorithms**

# %% [markdown]
# ## **Spectral Clustering**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
num_clusters = 2
spectral = SpectralClustering(n_clusters=num_clusters, affinity='nearest_neighbors', random_state=42)
df['Cluster'] = spectral.fit_predict(df_scaled)
# Out:
# <ipython-input-82-80e10b3efca7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cluster'] = spectral.fit_predict(df_scaled)

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['wage'], y=df['nr'], hue=df['Cluster'], palette="viridis", s=50)
plt.title("21BDS0099-Spectral Clustering Results")
plt.xlabel("wage")
plt.ylabel("nr")
plt.legend(title="Cluster")
plt.show()

# %% [markdown]
# ## **Hierarchical Agglomerative clustering**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# %%
plt.figure(figsize=(10, 5))
linked = linkage(df_scaled, method='ward')
dendrogram(linked)
plt.title("21BDS0099-Hierarchical Clustering Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Euclidean Distance")
plt.show()

# %% [markdown]
# ## **Outlier detection using Clustering**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
df['Cluster'] = dbscan.fit_predict(df_scaled)
# Out:
# <ipython-input-89-9c540fa98883>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cluster'] = dbscan.fit_predict(df_scaled)

# %%
df['Outlier'] = df['Cluster'] == -1
# Out:
# <ipython-input-90-eae31455906b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Outlier'] = df['Cluster'] == -1

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['wage'], y=df['nr'], hue=df['Cluster'], palette="viridis", s=50)
sns.scatterplot(x=df[df.Outlier]['wage'], y=df[df.Outlier]['nr'], color='red', label='Outlier', s=100, edgecolor='black')
plt.title("21BDS0099 - Outlier Detection using DBSCAN")
plt.xlabel("wage")
plt.ylabel("nr")
plt.legend()
plt.show()

# %%
num_outliers = df['Outlier'].sum()
print(f"Total outliers detected: {num_outliers}")
# Out:
# Total outliers detected: 26

# %% [markdown]
# # **Dimensionality Reduction**

# %% [markdown]
# ## **PCA**

# %%
from sklearn.decomposition import PCA

# %%
num_components = 2
pca = PCA(n_components=num_components)
df_pca = pca.fit_transform(df_scaled)

# %%
df_pca = pd.DataFrame(df_pca, columns=[f'PC{i+1}' for i in range(num_components)])

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df_pca['PC1'], y=df_pca['PC2'], palette="viridis", s=50)
plt.title("21BDS0099 - PCA Visualization")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Target Class")
plt.show()
# Out:
# <ipython-input-99-82d7ef56251f>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df_pca['PC1'], y=df_pca['PC2'], palette="viridis", s=50)
# <ipython-input-99-82d7ef56251f>:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Target Class")

# %% [markdown]
# # **Model Development and Evaluation**

# %%
krinith_df2 = krinith_df[['wage', 'nr']]

# %%
sns.heatmap(krinith_df2.corr(), square=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %%
sns.lmplot(x = 'wage', y = 'nr', data = krinith_df2)

# %%
krinith_x = krinith_df2[['wage']]
krinith_y = krinith_df2[['nr']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(krinith_x, krinith_y, test_size = 0.3, random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test, y_test)
# Out:
# 0.006711480084993227

# %%
y_pred=regressor.predict(X_test)
evaluate = pd.DataFrame({'Actual': y_test.values.flatten(),
'Predicted': y_pred.flatten()})
evaluate.head(10)
# Out:
#    Actual    Predicted
# 0    8501  5031.720796
# 1    1064  4646.231571
# 2    2038  4968.135011
# 3    5359  4982.527131
# 4    2075  4705.753688
# 5    8846  4871.976737
# 6    4791  4760.839224
# 7    1096  4886.401530
# 8    1434  4891.632971
# 9     110  4656.480263

# %%
evaluate.head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

print(f"R2 score: {r2_score(y_test, y_pred)}")
print(f"MAE score: {mean_absolute_error(y_test, y_pred)}")
print(f"MSE score: {mean_squared_error(y_test, y_pred)}")
# Out:
# R2 score: 0.006711480084993227
# MAE score: 2930.5578591820927
# MSE score: 12133251.096668273
